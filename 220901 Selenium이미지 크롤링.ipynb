# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

keyword = input('검색어 입력 : ')
url = 'https://www.google.com/search?q=' +keyword
url = url +'&rlz=1C1CHBD_koKR899KR899&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj7lbzD2_L5AhWGrVYBHb_JAEQQ_AUoAXoECAEQAw&biw=941&bih=929&dpr=1'
print(url)
# Out:
# 검색어 입력 : 갤럭시
# https://www.google.com/search?q=갤럭시&rlz=1C1CHBD_koKR899KR899&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj7lbzD2_L5AhWGrVYBHb_JAEQQ_AUoAXoECAEQAw&biw=941&bih=929&dpr=1

# %%
driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
driver.get(url)
time.sleep(2)

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.find_element_by_css_selector('#islmp > div > div > div.tmS4cc.blLOvc.snjnxc > div.gBPM8 > div.qvfT1 > div.YstHxe > input').click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
for i in range(11):
    if i>4:
        if i%5 ==0:
            try:
                driver.find_element_by_css_selector('#islmp > div > div > div.tmS4cc.blLOvc.snjnxc > div.gBPM8 > div.qvfT1 > div.YstHxe > input').click()
            except:
                pass
    time.sleep(1)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
html_source=driver.page_source
soup=bs(html_source, 'html.parser')
soup
# Out:
# <html dir="ltr" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.IK5OmUURd2E.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo932JinkSJHK92WgVjIV-Jwwyu3Rw/cb=gapi.loaded_0"></script><base href="https://www.google.com/"/><meta content="origin" name="referrer"/><script data-id="_gd" nonce="">window.WIZ_global_data = {"DpimGf":false,"EP1ykd":["/_/*","/a/cpanel","/a/cpanel/*","/about/careers/applications","/about/careers/applications-a","/about/careers/applications-a/*","/about/careers/applications/*","/about/careers/interview","/about/careers/interview/*","/buzz/c","/buzz/c/*","/cameos","/cameos/*","/cbk","/cbk/*","/coronavirus-map","/coronavirus-map/*","/covid19-map","/covid19-map/*","/covid19/exposurenotifications/select","/covid19/exposurenotifications/select/*","/discover/likes","/discover/likes/*","/display-ads-user-messaging-embed","/display-ads-user
# ...

# %%
img_url = soup.find('div',class_='tmS4cc').find_all('img')[0]['src']

# %%
urllib.request.urlretrieve(img_url,'C:/Users/sec/Desktop/Junseok/Untitled Folder/img_test.jpg')
# Out:
# ('C:/Users/sec/Desktop/Junseok/Untitled Folder/img_test.jpg',
#  <email.message.Message at 0x261bc7a59c8>)

# %%
fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
fName = os.listdir(fDir)
fName_dir = keyword+'0'
cnt = 0

while True:
    if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
        os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
        break #생성후 while문 빠져나감
    cnt+=1
    fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
    
print(fName_dir,' 폴더 생성')
# Out:
# 갤럭시0  폴더 생성

# %%
img_list = soup.find('div',class_='islrc').find_all('img')

# %%
len(img_list)
# Out:
# 932

# %%
cnt = 0
for img_url in tqdm(img_list):
    try:
        tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
        urllib.request.urlretrieve(img_url['src'],
                                  tmp_name+fName_dir+'/'+keyword+str(cnt)+'.jpg')
        cnt+=1
    except:
        tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
        urllib.request.urlretrieve(img_url['data-src'],
                                  tmp_name+fName_dir+'/'+keyword+str(cnt)+'.jpg')
        cnt+=1
        pass
# Out:
#  64%|███████████████████████████████████████████████████▌                            | 600/932 [04:26<02:56,  1.88it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-c8353e249a03> in <module>
#       4         tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
# ----> 5         urllib.request.urlretrieve(img_url['src'],
#       6                                   tmp_name+fName_dir+'/'+keyword+str(cnt)+'.jpg')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1320         and throws an exception if it's not there."""
# -> 1321         return self.attrs[key]
#    1322
#
# KeyError: 'src'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-144-c8353e249a03> in <module>
# ...

# %%
# Out:
# 600

# %%
# %%writefile google_img_crawling.py # 주피터파일이 있는 파일 디렉토리에 해당이름으로 저장
# from selenium import webdriver
# from bs4 import BeautifulSoup as bs
# import urllib.request
# import os
# from tqdm import tqdm
# import time
#
# keyword = input('검색어 입력 : ')
# url = 'https://www.google.com/search?q=' +keyword
# url = url +'&rlz=1C1CHBD_koKR899KR899&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj7lbzD2_L5AhWGrVYBHb_JAEQQ_AUoAXoECAEQAw&biw=941&bih=929&dpr=1'
#
# driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
# driver.get(url)
# time.sleep(2)
#
# for i in range(10):
#     if i>4:
#         if i%5 ==0:
#             try:
#                 driver.find_element_by_css_selector('#islmp > div > div > div.tmS4cc.blLOvc.snjnxc > div.gBPM8 > div.qvfT1 > div.YstHxe > input').click()
#             except:
#                 pass
#     time.sleep(1)
#     driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
#
# html_source=driver.page_source
# soup=bs(html_source, 'html.parser')
#
# img_list = soup.find('div',class_='islrc').find_all('img')
# img_url = soup.find('div',class_='islrc').find_all('img')[0]['src']
# len(img_list)
#
# # 저장폴더 생성
# fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
# fName = os.listdir(fDir)
# # 저장폴더 존재여부 확인
# fName_dir = keyword+'0'
# cnt = 0
#
# while True:
#     if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
#         os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
#         break #생성후 while문 빠져나감
#     cnt+=1
#     fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
#
# print(fDir+fName_dir,'로폴더 생성')
#
# cnt = 0
# for img_url in tqdm(img_list, desc = '저장중...'):
#     tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir + '/' + keyword + str(cnt) + '.jpg'
#     try:
#         urllib.request.urlretrieve(img_url['src'],tmp_name)
#     except:
#         urllib.request.urlretrieve(img_url['data-src'],tmp_name)
#     cnt+=1
#
# driver.close()
# Out:
# UsageError: unrecognized arguments: # 주피터파일이 있는 파일 디렉토리에 해당이름으로 저장

# %%
# 구글 이미지 크롤링

from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

keyword = input('검색어 입력 : ')
url = 'https://www.google.com/search?q=' +keyword
url = url +'&rlz=1C1CHBD_koKR899KR899&source=lnms&tbm=isch&sa=X&ved=2ahUKEwj7lbzD2_L5AhWGrVYBHb_JAEQQ_AUoAXoECAEQAw&biw=941&bih=929&dpr=1'

driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
driver.get(url)
time.sleep(2)

for i in range(10):
    if i>4:
        if i%5 ==0:
            try:
                driver.find_element_by_css_selector('#islmp > div > div > div.tmS4cc.blLOvc.snjnxc > div.gBPM8 > div.qvfT1 > div.YstHxe > input').click()
            except:
                pass
    time.sleep(1)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    
html_source=driver.page_source
soup=bs(html_source, 'html.parser')

img_list = soup.find('div',class_='islrc').find_all('img')
img_url = soup.find('div',class_='islrc').find_all('img')[0]['src']
len(img_list)

# 저장폴더 생성
fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
fName = os.listdir(fDir)
# 저장폴더 존재여부 확인
fName_dir = keyword+'0'
cnt = 0

while True:
    if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
        os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
        break #생성후 while문 빠져나감
    cnt+=1
    fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
    
print(fDir+fName_dir,'로폴더 생성')

cnt = 0
for img_url in tqdm(img_list, desc = '저장중...'):
    tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir + '/' + keyword + str(cnt) + '.jpg'
    try:
        urllib.request.urlretrieve(img_url['src'],tmp_name)
    except:
        urllib.request.urlretrieve(img_url['data-src'],tmp_name)
    cnt+=1

driver.close()
# Out:
# 검색어 입력 : 스타벅스
# ...
# 저장중...:   2%|█▋                                                                   | 19/778 [00:00<00:04, 188.23it/s]
# C:/Users/sec/Desktop/Junseok/Untitled Folder/스타벅스0 로폴더 생성
# ...
# 저장중...:  57%|███████████████████████████████████████                              | 441/778 [04:12<02:51,  1.96it/s]
# ...
# ...
# 저장중...: 100%|█████████████████████████████████████████████████████████████████████| 778/778 [06:48<00:00,  1.91it/s]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

keyword = input('검색어 입력 : ')
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' +keyword

driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
driver.get(url)
time.sleep(2)
# Out:
# 검색어 입력 : 에어컨

# %%
for i in range(10):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1)

# %%
html_source=driver.page_source
soup=bs(html_source, 'html.parser')

# %%
soup.find('div', class_='photo_group _listGrid').find_all('img')[0]['src']
# Out:
# 'https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_1189339%2F11893391620.jpg&type=l340_165'

# %%
img_list = soup.find('div', class_='photo_group _listGrid').find_all('img')
img_url = soup.find('div', class_='photo_group _listGrid').find_all('img')[0]['src']
len(img_list)
# Out:
# 576

# %%
# 저장폴더 생성
fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
fName = os.listdir(fDir)
# 저장폴더 존재여부 확인
fName_dir = keyword+'0'
cnt = 0
while True:
    if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
        os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
        break #생성후 while문 빠져나감
    cnt+=1
    fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
    
print(fDir+fName_dir,'로폴더 생성')
# Out:
# C:/Users/sec/Desktop/Junseok/Untitled Folder/에어컨0 로폴더 생성

# %%
cnt = 0
for img_url in tqdm(img_list, desc = '저장중...'):
    tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir + '/' + keyword + str(cnt) + '.jpg'
    try:
        urllib.request.urlretrieve(img_url['src'],tmp_name)
    except:
        urllib.request.urlretrieve(img_url['data-src'],tmp_name)
    cnt+=1

driver.close()
# Out:
# ...
# 저장중...: 100%|█████████████████████████████████████████████████████████████████████| 576/576 [01:19<00:00,  7.28it/s]

# %%
# 네이버 이미지 크롤링
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

keyword = input('검색어 입력 : ')
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' +keyword

driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
driver.get(url)
time.sleep(2)


for i in range(10):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1.5)    

html_source=driver.page_source
soup=bs(html_source, 'html.parser')

img_list = soup.find('div', class_='photo_group _listGrid').find_all('img')
img_url = soup.find('div', class_='photo_group _listGrid').find_all('img')[0]['src']
print(len(img_list))

# 저장폴더 생성
fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
fName = os.listdir(fDir)
# 저장폴더 존재여부 확인
fName_dir = keyword+'0'
cnt = 0
while True:
    if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
        os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
        break #생성후 while문 빠져나감
    cnt+=1
    fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
    
print(fDir+fName_dir,'로폴더 생성')

time.sleep(5)
cnt = 0
for img_url in tqdm(img_list, desc = '저장중...'):
    tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir + '/' + keyword + str(cnt) + '.jpg'
    try:
        urllib.request.urlretrieve(img_url['src'],tmp_name)
    except:
        urllib.request.urlretrieve(img_url['data-src'],tmp_name)
    cnt+=1


driver.close()
# Out:
# 검색어 입력 : 화이팅
# 542
# C:/Users/sec/Desktop/Junseok/Untitled Folder/화이팅0 로폴더 생성
# ...
# 저장중...: 100%|█████████████████████████████████████████████████████████████████████| 542/542 [01:02<00:00,  8.64it/s]

# %%
PATH ='C:/Users/sec/Desktop/Junseok/Untitled Folder/'+fName_dir 

photo_list = []

for f in os.listdir(PATH):
    if 'jpg' in f:
        photo_list.append(f)
        
photo_size = list(map(lambda x: os.path.getsize(PATH + '/' + x), photo_list))


import pandas as pd
fsp = pd.DataFrame({'filename_raw':photo_list, 'size':photo_size})

print('사진의 갯수 :', len(fsp))

pvc = pd.DataFrame({'filename_raw':fsp['filename_raw'].value_counts().index, 'fn_counts':fsp['filename_raw'].value_counts().values})   
psvc = pd.DataFrame({'size':fsp['size'].value_counts().index, 'size_counts':fsp['size'].value_counts().values})   

fsp = pd.merge(fsp, pvc, how = 'left', on = 'filename_raw')
fsp = pd.merge(fsp, psvc, how = 'left', on = 'size')

idx = fsp[fsp['size'] ==42].index
fsp_nsn = fsp.drop(idx)
fsp_nsn = fsp_nsn.sort_values(['filename_raw'], ascending = True)


print('남은 사진의 갯수 : {}\n지워진 사진의 갯수 : {}'.format(len(fsp_nsn), len(fsp)-len(fsp_nsn)))
# 중복제거된 것들은 delete 리스트에 넣어주기
delete =[]
delete = list(fsp[~fsp['filename_raw'].isin(fsp_nsn['filename_raw'])]['filename_raw'])

# result : 처음(fsp)데이터에서 - delete를 제외한 것
result = list(fsp[~fsp['filename_raw'].isin(delete)]['filename_raw'])

print('남길 목록 : ', len(result),'삭제할 목록 :', len(delete))

import shutil
os.mkdir(PATH+'/Result')
os.mkdir(PATH+'/Delete')
Result_dir = PATH+'/Result'
Delete_dir = PATH+'/Delete'
for i in result:
    shutil.move(PATH+'/'+i,Result_dir)
    
for i in delete:
    shutil.move(PATH+'/'+i, Delete_dir)
# Out:
# 사진의 갯수 : 542
# 남은 사진의 갯수 : 119
# 지워진 사진의 갯수 : 423
# 남길 목록 :  119 삭제할 목록 : 423

# %%
# %%writefile google_img_crawling.py 
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import urllib.request
import os
from tqdm import tqdm
import time

keyword = input('검색어 입력 : ')
url = 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=' +keyword

driver = webdriver.Chrome('C:/Users/sec/Desktop/Junseok/Untitled Folder/chromedriver.exe')
driver.get(url)
time.sleep(2)


for i in range(10):
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    time.sleep(1.5)    

html_source=driver.page_source
soup=bs(html_source, 'html.parser')

img_list = soup.find('div', class_='photo_group _listGrid').find_all('img')
img_url = soup.find('div', class_='photo_group _listGrid').find_all('img')[0]['src']
print(len(img_list))

# 저장폴더 생성
fDir = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'
fName = os.listdir(fDir)
# 저장폴더 존재여부 확인
fName_dir = keyword+'0'
cnt = 0
while True:
    if fName_dir not in fName: # 새로 생성한 폴더가 현재 저장 위치에 있으면
        os.makedirs(fDir+fName_dir) # 없ㅇ면 현재 이름으로 생성
        break #생성후 while문 빠져나감
    cnt+=1
    fName_dir=keyword+str(cnt) # 새로운 폴더명 생성
    
print(fDir+fName_dir,'로폴더 생성')

time.sleep(5)
cnt = 0
for img_url in tqdm(img_list, desc = '저장중...'):
    tmp_name = 'C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir + '/' + keyword + str(cnt) + '.jpg'
    try:
        urllib.request.urlretrieve(img_url['src'],tmp_name)
    except:
        urllib.request.urlretrieve(img_url['data-src'],tmp_name)
    cnt+=1
    time.sleep(0.1)

driver.close()
# Out:
# Overwriting google_img_crawling.py

# %%
fName_dir
# Out:
# '에어컨0'

# %%
PATH ='C:/Users/sec/Desktop/Junseok/Untitled Folder/'+ fName_dir

# %%
photo_list = []

for f in os.listdir(PATH):
    if 'jpg' in f:
        photo_list.append(f)

# %%
photo_list
# Out:
# ['에어컨0.jpg',
#  '에어컨1.jpg',
#  '에어컨10.jpg',
#  '에어컨100.jpg',
#  '에어컨101.jpg',
#  '에어컨102.jpg',
#  '에어컨103.jpg',
#  '에어컨104.jpg',
#  '에어컨105.jpg',
#  '에어컨106.jpg',
#  '에어컨107.jpg',
#  '에어컨108.jpg',
#  '에어컨109.jpg',
#  '에어컨11.jpg',
#  '에어컨110.jpg',
#  '에어컨111.jpg',
#  '에어컨112.jpg',
#  '에어컨113.jpg',
#  '에어컨114.jpg',
#  '에어컨115.jpg',
#  '에어컨116.jpg',
#  '에어컨117.jpg',
#  '에어컨118.jpg',
#  '에어컨119.jpg',
#  '에어컨12.jpg',
#  '에어컨120.jpg',
#  '에어컨121.jpg',
#  '에어컨122.jpg',
#  '에어컨123.jpg',
#  '에어컨124.jpg',
#  '에어컨125.jpg',
#  '에어컨126.jpg',
#  '에어컨127.jpg',
#  '에어컨128.jpg',
#  '에어컨129.jpg',
#  '에어컨13.jpg',
#  '에어컨130.jpg',
#  '에어컨131.jpg',
#  '에어컨132.jpg',
#  '에어컨133.jpg',
#  '에어컨134.jpg',
#  '에어컨135.jpg',
#  '에어컨136.jpg',
#  '에어컨137.jpg',
#  '에어컨138.jpg',
#  '에어컨139.jpg',
#  '에어컨14.jpg',
#  '에어컨140.jpg',
#  '에어컨141.jpg',
#  '에어컨142.jpg',
#  '에어컨143.jpg',
#  '에어컨144.jpg',
#  '에어컨145.jpg',
#  '에어컨146.jpg',
#  '에어컨147.jpg',
#  '에어컨148.jpg',
#  '에어컨149.jpg',
#  '에어컨15.jpg',
#  '에어컨150.jpg',
# ...

# %%
photo_size = list(map(lambda x: os.path.getsize(PATH + '/' + x), photo_list))

# %%
import pandas as pd
fsp = pd.DataFrame({'filename_raw':photo_list, 'size':photo_size})

print('사진의 갯수 :', len(fsp))
# Out:
# 사진의 갯수 : 576

# %%
fsp
# Out:
#     filename_raw   size
# 0       에어컨0.jpg   4168
# 1       에어컨1.jpg  31174
# 2      에어컨10.jpg   2004
# 3     에어컨100.jpg     42
# 4     에어컨101.jpg   1464
# ..           ...    ...
# 571    에어컨95.jpg     42
# 572    에어컨96.jpg     42
# 573    에어컨97.jpg     42
# 574    에어컨98.jpg   1464
# 575    에어컨99.jpg     42
#
# [576 rows x 2 columns]

# %%
pvc = pd.DataFrame({'filename_raw':fsp['filename_raw'].value_counts().index, 'fn_counts':fsp['filename_raw'].value_counts().values})   
psvc = pd.DataFrame({'size':fsp['size'].value_counts().index, 'size_counts':fsp['size'].value_counts().values})   

fsp = pd.merge(fsp, pvc, how = 'left', on = 'filename_raw')
fsp = pd.merge(fsp, psvc, how = 'left', on = 'size')

fsp.sample(2)
# Out:
#     filename_raw  size  fn_counts  size_counts
# 152   에어컨235.jpg  1464          1           23
# 229   에어컨304.jpg  1464          1           23

# %%
fsp
# Out:
#     filename_raw   size  fn_counts  size_counts
# 0       에어컨0.jpg   4168          1            1
# 1       에어컨1.jpg  31174          1            1
# 2      에어컨10.jpg   2004          1            1
# 3     에어컨100.jpg     42          1          427
# 4     에어컨101.jpg   1464          1           23
# ..           ...    ...        ...          ...
# 571    에어컨95.jpg     42          1          427
# 572    에어컨96.jpg     42          1          427
# 573    에어컨97.jpg     42          1          427
# 574    에어컨98.jpg   1464          1           23
# 575    에어컨99.jpg     42          1          427
#
# [576 rows x 4 columns]

# %%
idx = fsp[fsp['size'] ==42].index
fsp_nsn = fsp.drop(idx)
fsp_nsn = fsp_nsn.sort_values(['filename_raw'], ascending = True)

# %%
fsp_nsn = fsp_nsn.sort_values(['filename_raw'], ascending = True)

# %%
fsp_nsn
# Out:
#     filename_raw   size  fn_counts  size_counts
# 0       에어컨0.jpg   4168          1            1
# 1       에어컨1.jpg  31174          1            1
# 2      에어컨10.jpg   2004          1            1
# 4     에어컨101.jpg   1464          1           23
# 13     에어컨11.jpg  10082          1            1
# ..           ...    ...        ...          ...
# 543     에어컨7.jpg   1464          1           23
# 544    에어컨70.jpg   1464          1           23
# 547    에어컨73.jpg   1464          1           23
# 565     에어컨9.jpg  15872          1            1
# 574    에어컨98.jpg   1464          1           23
#
# [149 rows x 4 columns]

# %%
print('남은 사진의 갯수 : {}\n지워진 사진의 갯수 : {}'.format(len(fsp_nsn), len(fsp)-len(fsp_nsn)))
# 중복제거된 것들은 delete 리스트에 넣어주기
delete =[]
delete = list(fsp[~fsp['filename_raw'].isin(fsp_nsn['filename_raw'])]['filename_raw'])

# result : 처음(fsp)데이터에서 - delete를 제외한 것
result = list(fsp[~fsp['filename_raw'].isin(delete)]['filename_raw'])

print('남길 목록 : ', len(result),'삭제할 목록 :', len(delete))
# Out:
# 남은 사진의 갯수 : 149
# 지워진 사진의 갯수 : 427

# %%
# 중복제거된 것들은 delete 리스트에 넣어주기
delete =[]
delete = list(fsp[~fsp['filename_raw'].isin(fsp_nsn['filename_raw'])]['filename_raw'])

print('삭제할 목록 :', len(delete))
# Out:
# 삭제할 목록 : 427

# %%
# result : 처음(fsp)데이터에서 - delete를 제외한 것
result = list(fsp[~fsp['filename_raw'].isin(delete)]['filename_raw'])

print('남길 목록 : ', len(result))
# Out:
# 남길 목록 :  149

# %%
import shutil
os.mkdir(PATH+'/Result')
os.mkdir(PATH+'/Delete')
Result_dir = PATH+'/Result'
Delete_dir = PATH+'/Delete'
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-123-61280312229e> in <module>
#       1 import shutil
# ----> 2 os.mkdir(PATH+'/Result')
#       3 os.mkdir(PATH+'/Delete')
#       4 Result_dir = PATH+'/Result'
#       5 Delete_dir = PATH+'/Delete'
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:/Users/sec/Desktop/Junseok/Untitled Folder/에어컨0/Result'

# %%
for i in result:
    shutil.move(PATH+'/'+i,Result_dir)
    
for i in delete:
    shutil.move(PATH+'/'+i, Delete_dir)

# %%
PATH ='C:/Users/sec/Desktop/Junseok/Untitled Folder/'+fName_dir 

photo_list = []

for f in os.listdir(PATH):
    if 'jpg' in f:
        photo_list.append(f)
        
photo_size = list(map(lambda x: os.path.getsize(PATH + '/' + x), photo_list))


import pandas as pd
fsp = pd.DataFrame({'filename_raw':photo_list, 'size':photo_size})

print('사진의 갯수 :', len(fsp))

pvc = pd.DataFrame({'filename_raw':fsp['filename_raw'].value_counts().index, 'fn_counts':fsp['filename_raw'].value_counts().values})   
psvc = pd.DataFrame({'size':fsp['size'].value_counts().index, 'size_counts':fsp['size'].value_counts().values})   

fsp = pd.merge(fsp, pvc, how = 'left', on = 'filename_raw')
fsp = pd.merge(fsp, psvc, how = 'left', on = 'size')

idx = fsp[fsp['size'] ==42].index
fsp_nsn = fsp.drop(idx)
fsp_nsn = fsp_nsn.sort_values(['filename_raw'], ascending = True)


print('남은 사진의 갯수 : {}\n지워진 사진의 갯수 : {}'.format(len(fsp_nsn), len(fsp)-len(fsp_nsn)))
# 중복제거된 것들은 delete 리스트에 넣어주기
delete =[]
delete = list(fsp[~fsp['filename_raw'].isin(fsp_nsn['filename_raw'])]['filename_raw'])

# result : 처음(fsp)데이터에서 - delete를 제외한 것
result = list(fsp[~fsp['filename_raw'].isin(delete)]['filename_raw'])

print('남길 목록 : ', len(result),'삭제할 목록 :', len(delete))

import shutil
os.mkdir(PATH+'/Result')
os.mkdir(PATH+'/Delete')
Result_dir = PATH+'/Result'
Delete_dir = PATH+'/Delete'
for i in result:
    shutil.move(PATH+'/'+i,Result_dir)
    
for i in delete:
    shutil.move(PATH+'/'+i, Delete_dir)
# Out:
# 사진의 갯수 : 576
# 남은 사진의 갯수 : 131
# 지워진 사진의 갯수 : 445
# 남길 목록 :  0 삭제할 목록 : 576
